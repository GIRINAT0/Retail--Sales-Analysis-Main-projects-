# %%
import  pandas as pd

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\mohan\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\mohan\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
engine=create_engine("mysql+pymysql://root:1234@localhost:3306/retail_analytics")

# %%
orders_df=pd.read_sql("select * from retail_analytics.orders;",engine)

# %%
orders_df
# Out:
#       order_id  customer_id  order_status Orderstatus  order_date  \
# 0            1          259             4   Delivered  2016-01-01
# 1            2         1212             4   Delivered  2016-01-02
# 2            3          523             4   Delivered  2016-01-03
# 3            4          175             4   Delivered  2016-01-04
# 4            5         1324             4   Delivered  2016-01-05
# ...        ...          ...           ...         ...         ...
# 1610      1611            6             3     Shipped  2020-05-29
# 1611      1612            3             3     Shipped  2020-05-30
# 1612      1613            1             3     Shipped  2020-05-31
# 1613      1614          135             3     Shipped  2020-06-01
# 1614      1615          136             3     Shipped  2020-06-02
#
#      required_date shipped_date  store_id  staff_id
# 0       2016-01-03   2016-01-03         1         2
# 1       2016-01-04   2016-01-04         2         6
# ...

# %%
order_items_df=pd.read_sql("select* from retail_analytics.order_items;",engine)

# %%
products_df=pd.read_sql("select* from retail_analytics.products;",engine)

# %%
products_df
# Out:
#      product_id                          product_name  brand_id  category_id  \
# 0             1                       Trek 820 - 2016         9            6
# 1             2    Ritchey Timberwolf Frameset - 2016         5            6
# 2             3       Surly Wednesday Frameset - 2016         8            6
# 3             4              Trek Fuel EX 8 29 - 2016         9            6
# 4             5          Heller Shagamaw Frame - 2016         3            6
# ..          ...                                   ...       ...          ...
# 316         317          Trek Checkpoint ALR 5 - 2019         9            7
# 317         318  Trek Checkpoint ALR 5 Women's - 2019         9            7
# 318         319   Trek Checkpoint SL 5 Women's - 2019         9            7
# 319         320           Trek Checkpoint SL 6 - 2019         9            7
# 320         321   Trek Checkpoint ALR Frameset - 2019         9            7
#
#      model_year  list_price
# ...

# %%
order_items_df
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount  \
# 0            1        1          20         1         600         0
# 1            1        2           8         2        1800         0
# 2            1        3          10         2        1549         0
# 3            1        4          16         2         600         0
# 4            1        5           4         1        2900         0
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2        2300         0
# 4718      1614        3         213         2         270         0
# 4719      1615        1         197         2        2300         0
# 4720      1615        2         214         1         900         0
# 4721      1615        3         182         1        2500         0
#
#       Total_price                                    Product_name
# 0             600  Electra Townie Original 7D EQ - Women's - 2016
# ...

# %%
customers_df=pd.read_sql("select* from retail_analytics.customers_dataset;",engine)

# %%
customers_df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# 1444         1445       Ester   Acevedo              NA
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
customers_df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# 1444         1445       Ester   Acevedo              NA
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
customers_df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# 1444         1445       Ester   Acevedo              NA
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
customers_df.describe()
# Out:
#        customer_id      zip_code
# count  1445.000000   1445.000000
# mean    723.000000  34200.015225
# std     417.279882  34733.933551
# min       1.000000  10002.000000
# 25%     362.000000  11419.000000
# 50%     723.000000  11967.000000
# 75%    1084.000000  76110.000000
# max    1445.000000  95993.000000

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\mohan\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
product_price=order_items_df.groupby('Product_name')['Total_price'].sum()
product_price=product_price.reset_index()

# %%
product_price
# Out:
#                                          Product_name  Total_price
# 0    Electra Amsterdam Fashion 3i Ladies' - 2017/2018         4500
# 1         Electra Amsterdam Fashion 7i Ladies' - 2017        44000
# 2           Electra Amsterdam Original 3i - 2015/2017        21120
# 3        Electra Amsterdam Original 3i Ladies' - 2017        20460
# 4              Electra Amsterdam Royal 8i - 2017/2018         1260
# ..                                                ...          ...
# 273                           Trek X-Caliber 8 - 2017        35000
# 274                           Trek X-Caliber 8 - 2018         3000
# 275                    Trek X-Caliber Frameset - 2018         6000
# 276                                Trek XM700+ - 2018        28000
# 277                        Trek XM700+ Lowstep - 2018        24500
#
# [278 rows x 2 columns]

# %%
product_price.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_name  278 non-null    str
#  1   Total_price   278 non-null    int64
# dtypes: int64(1), str(1)
# memory usage: 4.5 KB

# %%
product_price.value_counts()
product_price=product_price.head(10)

# %%
 product_price=product_price.sort_values(by='Total_price',ascending=False)

# %%
plt.bar(product_price['Product_name'],product_price['Total_price'])
plt.title('Distribution of product price')
plt.show()

# %%
product_price
# Out:
#                                        Product_name  Total_price
# 6                Electra Cruiser 1 (24-Inch) - 2016        79920
# 1       Electra Amsterdam Fashion 7i Ladies' - 2017        44000
# 2         Electra Amsterdam Original 3i - 2015/2017        21120
# 3      Electra Amsterdam Original 3i Ladies' - 2017        20460
# 0  Electra Amsterdam Fashion 3i Ladies' - 2017/2018         4500
# 5          Electra Amsterdam Royal 8i Ladies - 2018         3600
# 7                Electra Cruiser 1 - 2016/2017/2018         1890
# 8                  Electra Cruiser 1 Ladies' - 2018         1620
# 4            Electra Amsterdam Royal 8i - 2017/2018         1260
# 9                Electra Cruiser 1 Tall - 2016/2018          270

# %%
plt.pie(product_price['Total_price'],labels=product_price['Product_name'],autopct='%1.1f%%')
plt.title('Distribution of product percent')
plt.show()

# %%
order_items_df
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount  \
# 0            1        1          20         1         600         0
# 1            1        2           8         2        1800         0
# 2            1        3          10         2        1549         0
# 3            1        4          16         2         600         0
# 4            1        5           4         1        2900         0
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2        2300         0
# 4718      1614        3         213         2         270         0
# 4719      1615        1         197         2        2300         0
# 4720      1615        2         214         1         900         0
# 4721      1615        3         182         1        2500         0
#
#       Total_price                                    Product_name
# 0             600  Electra Townie Original 7D EQ - Women's - 2016
# ...

# %%
orders_df
# Out:
#       order_id  customer_id  order_status Orderstatus  order_date  \
# 0            1          259             4   Delivered  2016-01-01
# 1            2         1212             4   Delivered  2016-01-02
# 2            3          523             4   Delivered  2016-01-03
# 3            4          175             4   Delivered  2016-01-04
# 4            5         1324             4   Delivered  2016-01-05
# ...        ...          ...           ...         ...         ...
# 1610      1611            6             3     Shipped  2020-05-29
# 1611      1612            3             3     Shipped  2020-05-30
# 1612      1613            1             3     Shipped  2020-05-31
# 1613      1614          135             3     Shipped  2020-06-01
# 1614      1615          136             3     Shipped  2020-06-02
#
#      required_date shipped_date  store_id  staff_id
# 0       2016-01-03   2016-01-03         1         2
# 1       2016-01-04   2016-01-04         2         6
# ...

# %%
customers_df
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# 1444         1445       Ester   Acevedo              NA
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
product_year =products_df.groupby('model_year')['list_price'].sum()
product_year=product_year.reset_index()

# %%
product_year
# Out:
#    model_year  list_price
# 0        2016       25488
# 1        2017      108795
# 2        2018      338330
# 3        2019       15500

# %%
plt.plot(product_year['model_year'],product_year['list_price'])
plt.grid()
plt.title("Analysis of model_year & price")
plt.xlabel("modelyear")
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
 pip install  seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\mohan\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.boxplot(data=product_price, x='Product_name', y='Total_price')

plt.title('Distribution Of product price')
# Out:
# Text(0.5, 1.0, 'Distribution Of product price')

# %%
sns.histplot(data=product_price,x='Total_price')
plt.title('Ditribution of total price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
orders_df
# Out:
#       order_id  customer_id  order_status Orderstatus  order_date  \
# 0            1          259             4   Delivered  2016-01-01
# 1            2         1212             4   Delivered  2016-01-02
# 2            3          523             4   Delivered  2016-01-03
# 3            4          175             4   Delivered  2016-01-04
# 4            5         1324             4   Delivered  2016-01-05
# ...        ...          ...           ...         ...         ...
# 1610      1611            6             3     Shipped  2020-05-29
# 1611      1612            3             3     Shipped  2020-05-30
# 1612      1613            1             3     Shipped  2020-05-31
# 1613      1614          135             3     Shipped  2020-06-01
# 1614      1615          136             3     Shipped  2020-06-02
#
#      required_date shipped_date  store_id  staff_id
# 0       2016-01-03   2016-01-03         1         2
# 1       2016-01-04   2016-01-04         2         6
# ...

# %%
orders_df
# Out:
#       order_id  customer_id  order_status Orderstatus  order_date  \
# 0            1          259             4   Delivered  2016-01-01
# 1            2         1212             4   Delivered  2016-01-02
# 2            3          523             4   Delivered  2016-01-03
# 3            4          175             4   Delivered  2016-01-04
# 4            5         1324             4   Delivered  2016-01-05
# ...        ...          ...           ...         ...         ...
# 1610      1611            6             3     Shipped  2020-05-29
# 1611      1612            3             3     Shipped  2020-05-30
# 1612      1613            1             3     Shipped  2020-05-31
# 1613      1614          135             3     Shipped  2020-06-01
# 1614      1615          136             3     Shipped  2020-06-02
#
#      required_date shipped_date  store_id  staff_id
# 0       2016-01-03   2016-01-03         1         2
# 1       2016-01-04   2016-01-04         2         6
# ...

# %%
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])

# %%
order_value = order_items_df.groupby('order_id')['Total_price'].sum().reset_index()

# %%
order_value.rename(columns={'total_price':'order_value'},inplace = True)

# %%
orders_merged = pd.merge(orders_df, order_value, on='order_id')

# %%
orders_merged
# Out:
#       order_id  customer_id  order_status Orderstatus order_date  \
# 0            1          259             4   Delivered 2016-01-01
# 1            2         1212             4   Delivered 2016-01-02
# 2            3          523             4   Delivered 2016-01-03
# 3            4          175             4   Delivered 2016-01-04
# 4            5         1324             4   Delivered 2016-01-05
# ...        ...          ...           ...         ...        ...
# 1610      1611            6             3     Shipped 2020-05-29
# 1611      1612            3             3     Shipped 2020-05-30
# 1612      1613            1             3     Shipped 2020-05-31
# 1613      1614          135             3     Shipped 2020-06-01
# 1614      1615          136             3     Shipped 2020-06-02
#
#      required_date shipped_date  store_id  staff_id  Total_price
# 0       2016-01-03   2016-01-03         1         2        11398
# ...

# %%
reference_date = orders_merged['order_date'].max() + pd.Timedelta(days=1)

# %%
rfm = orders_merged.groupby('customer_id').agg({'order_date': lambda x: 
(reference_date - x.max()).days, 'order_id': 'count','Total_price':'sum'}).reset_index()

# %%
rfm.columns = ['customer_id', 'recency', 'frequency', 'monetary']

# %%
rfm
# Out:
#       customer_id  recency  frequency  monetary
# 0               1        3          3     30646
# 1               2      107          3     21654
# 2               3        4          3     26250
# 3               4       60          3     24199
# 4               5       72          3     19443
# ...           ...      ...        ...       ...
# 1440         1441      250          1     10498
# 1441         1442      580          1      7842
# 1442         1443     1058          1     11238
# 1443         1444     1000          1      1750
# 1444         1445      192          1     10000
#
# [1445 rows x 4 columns]

# %%
import sqlite3

# %%
conn = sqlite3.connect("retail_analytics")

# %%
rfm.to_sql("rfm", con=engine, if_exists="replace", index=False)
# Out:
# 1445

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:1234@localhost/retail_analytics")
